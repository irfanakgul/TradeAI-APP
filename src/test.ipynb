# %%
from db_cloud_func import fn_read_data_cloud,fn_write_cloud
# Out:
# ========| ('user_yasin', 'trade_app') |========
# *** ✅ SUCCESSFUL CLOUD CONNECTION ⛓️ ***

# %%
df = fn_read_data_cloud('raw','bist_daily_archive')

# %%
df
# Out:
#        SYMBOL            TIMESTAMP         TS       OPEN       HIGH  \
# 0       ACSEL  2020-10-16 00:00:00 2020-10-16  17.700001  17.809999
# 1       ACSEL  2020-10-19 00:00:00 2020-10-19  17.650000  17.799999
# 2       ACSEL  2020-10-20 00:00:00 2020-10-20  17.530001  18.650000
# 3       ACSEL  2020-10-21 00:00:00 2020-10-21  18.299999  18.700001
# 4       ACSEL  2020-10-22 00:00:00 2020-10-22  18.000000  18.490000
# ...       ...                  ...        ...        ...        ...
# 736500  ACSEL  2020-10-09 00:00:00 2020-10-09  18.410000  19.020000
# 736501  ACSEL  2020-10-12 00:00:00 2020-10-12  18.799999  18.799999
# 736502  ACSEL  2020-10-13 00:00:00 2020-10-13  17.870001  17.900000
# 736503  ACSEL  2020-10-14 00:00:00 2020-10-14  17.290001  18.200001
# 736504  ACSEL  2020-10-15 00:00:00 2020-10-15  17.950001  18.110001
#
#               LOW      CLOSE    VOLUME      SOURCE  \
# 0       17.430000  17.540001  137850.0  yahooquery
# ...
